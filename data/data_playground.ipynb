# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('interim/dataset_clean.csv')
df
# Out:
#         type  IP_Address  URL_Length  URL_Shortening  \
# 0          0         1.0        59.0             1.0
# 1          1         1.0        77.0             1.0
# 2          0         1.0        51.0            -1.0
# 3          1         1.0        97.0             1.0
# 4          0         1.0        85.0             1.0
# ...      ...         ...         ...             ...
# 141209     1         1.0        38.0             1.0
# 141210     0         1.0        49.0             1.0
# 141211     1         1.0        73.0             1.0
# 141212     0         1.0        38.0             1.0
# 141213     1         1.0        44.0             1.0
#
#         Double_Slash_Redirect_After_HTTPS  Hyphen_in_Domain_Name  \
# 0                                     1.0                    1.0
# 1                                     1.0                    1.0
# 2                                     1.0                    1.0
# ...

# %%
df2 = pd.read_csv('processed/dataset_gabungan.csv')
df2
# Out:
#         original_index                                       url_original  \
# 0                    0  https://www.nationofblue.com/madness-tickets-s...
# 1                    3  http://damp.ringgatan.se/618e9jy89z\nfergumi.m...
# 2                    1  https://www.encyclopedia.farlex.com/vulgar+fra...
# 3                    4  http://bluga.com.ar/fran/googledocs/login.php?...
# 4                    2  https://www.canadianbusiness.com/article/49690...
# ...                ...                                                ...
# 141210            1135             http://europalamp.com/lacaixa/lacaixa/
# 141211             327  https://www.manta.com/c/mmsfrh7/john-c-moreau-dds
# 141212            1140  http://meet-memebersdirec.com/ads/newdocs/newd...
# 141213             328             https://www.twitter.com/thelionelblair
# 141214            1142       http://chun-engrg.com/Shaba/GD1/GD/index.php
#
#               type  IP_Address  URL_Length  URL_Shortening  \
# ...

# %%
df2.dtypes
# Out:
# original_index                         int64
# url_original                          object
# type                                  object
# IP_Address                           float64
# URL_Length                           float64
# URL_Shortening                       float64
# Double_Slash_Redirect_After_HTTPS    float64
# Hyphen_in_Domain_Name                float64
# Presence_of_Subdomain                float64
# Uses_HTTPS_Protocol                  float64
# Favicon_Source_Consistency           float64
# Custom_Port_Usage                    float64
# External_Resource_Ratio              float64
# External_Links_Ratio                 float64
# External_CSS_and_JS_Resources        float64
# External_Form_Submission             float64
# Form_Submits_to_Email_Address        float64
# HTTP_Response_Status_Content         float64
# Number_of_Redirects                  float64
# Mouseover_Link_Manipulation          float64
# Right_Click_Disabled                 float64
# ...

# %%
import re


# Pola regex URL shortener yang sudah diperbaiki
shortener_pattern = re.compile(
    # Tambahkan \b( di awal dan )\b di akhir
    r'\b(1url\.com|adf\.ly|bc\.vc|bit\.do|bit\.ly|bitly\.com|bkite\.com|bl\.ink|BudURL\.com|buzurl\.com|'
    r'cli\.gs|cur\.lv|cutt\.ly|cutt\.us|db\.tt|doiop\.com|ff\.im|fic\.kr|filoops\.info|go2l\.ink|'
    r'goo\.gl|is\.gd|ity\.im|j\.mp|Just\.as|kl\.am|link\.zip\.net|lnkd\.in|loopt\.us|migre\.me|'
    r'om\.ly|ow\.ly|ping\.fm|po\.st|post\.ly|prettylinkpro\.com|q\.gs|qr\.ae|qr\.net|rebrand\.ly|'
    r'rubyurl\.com|short\.ie|short\.io|short\.to|shorte\.st|snip\.ly|snipr\.com|snipurl\.com|'
    r'scrnch\.me|su\.pr|t\.co|t2m\.io|tiny\.cc|tinyurl\.com|to\.ly|tr\.im|tweez\.me|twit\.ac|'
    r'twitthis\.com|twurl\.nl|u\.bb|u\.to|url4\.eu|v\.gd|vzturl\.com|wp\.me|x\.co|yfrog\.com|yourls\.org)\b'
)

# Tambahkan kolom berdasarkan pencocokan regex
df2['url_shortener_true'] = df2['url_original'].apply(lambda x: 1 if shortener_pattern.search(x) else 0)

# %%
df2['url_shortener_true'].value_counts()
# Out:
# url_shortener_true
# 0    140752
# 1       463
# Name: count, dtype: int64

# %%
# ambil baris data yang memiliki url_shortener_true == 1
df_shortener = df2[df2['url_shortener_true'] == 1]
df_shortener
# Out:
#         original_index                                       url_original  \
# 162                359                                https://u.to/0IdAFA
# 830               1934                             https://tiny.cc/s1m9qy
# 1298              2969                              https://goo.gl/oezqhN
# 1914              4291                               http://goo.gl/BcfBK7
# 2136              4878                           http://ow.ly/6vlV306A8HS
# ...                ...                                                ...
# 139968           15934                              http://bit.ly/2dVdmh4
# 140244           16519                              http://bit.ly/1DbPA0z
# 140340           16723                              http://bit.ly/2cpzmQ0
# 140676           17368                               http://goo.gl/QMC1jd
# 140972             570  http://goo.gl/Q5wKEM???login-your-fbaccount=65...
#
#             type  IP_Address  URL_Length  URL_Shortening  \
# ...

# %%
# save to csv
df_shortener.to_csv('data playground/dataset_url_shortener.csv', index=False)
